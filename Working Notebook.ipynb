# %% [markdown]
# ## Depedencies

# %%
import sqlite3
import pandas as pd
import numpy as np
from pathlib import Path

# %% [markdown]
# ## Data Analysis & Manipulation

# %% [markdown]
# ### Census Data

# %%
census_data_path = str(Path.cwd().joinpath('calls/census_data/census_data.csv'))

# %%
census_df = pd.read_csv(census_data_path)

# %%
census_df.head()
# Out:
#            GEO.id GEO.id2 GEO.display-label   D001
# 0              Id     Id2         Geography  Total
# 1  8600000US06390   06390       ZCTA5 06390    236
# 2  8600000US10001   10001       ZCTA5 10001  21102
# 3  8600000US10002   10002       ZCTA5 10002  81410
# 4  8600000US10003   10003       ZCTA5 10003  56024

# %% [markdown]
# ### Database Connection

# %%
db_path = str(Path.cwd().joinpath('calls/app.db'))
conn = sqlite3.connect(db_path)
# cur = conn.cursor()

# %%
db = pd.read_sql_query('select * from locations', conn, index_col = "id")

# %%
db.zip = db.zip.astype('float', inplace = True)
db.zip = db.zip.astype('int')

# %%
db.head()
# Out:
#       zip  borough_id
# id
# 1   10027           1
# 2   11223           2
# 3   10461           3
# 4   10002           1
# 5   11385           4

# %%
# cur.close()
conn.close()

# %% [markdown]
# ### Reading in data
# Data read in and non-relevent columns dropped (same as from the original)

# %%
raw_data = pd.read_csv('calls/everything.csv', index_col=0, dtype={'incident_zip': str})
# Out:
# /anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2785: DtypeWarning: Columns (17) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
raw_data.drop(columns = ['Incident Address', 'Street Name', 'Cross Street 1', 'Cross Street 2',
       'Intersection Street 1', 'Intersection Street 2', 'Address Type',
       'City', 'Landmark', 'Park Facility Name', 'Park Borough', 'Vehicle Type',
       'Taxi Company Borough', 'Taxi Pick Up Location', 'Bridge Highway Name',
       'Bridge Highway Direction', 'Road Ramp', 'Bridge Highway Segment',
       'Latitude', 'Longitude', 'Status', 'Facility Type', 'Due Date', 'Resolution Description',
       'Resolution Action Updated Date', 'Community Board', 'BBL',], inplace=True)

# %%
raw_data.columns
# Out:
# Index(['Created Date', 'Closed Date', 'Agency', 'Agency Name',
#        'Complaint Type', 'Descriptor', 'Location Type', 'Incident Zip',
#        'Borough', 'X Coordinate (State Plane)', 'Y Coordinate (State Plane)',
#        'Open Data Channel Type', 'Location'],
#       dtype='object')

# %%
raw_data.head(1)
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 38490120    02/17/2018 10:03:19 AM  02/17/2018 10:42:22 AM   NYPD
#
#                                 Agency Name       Complaint Type  \
# Unique Key
# 38490120    New York City Police Department  Noise - Residential
#
#                   Descriptor               Location Type  Incident Zip  \
# Unique Key
# 38490120    Loud Music/Party  Residential Building/House       10027.0
#
#               Borough  X Coordinate (State Plane)  Y Coordinate (State Plane)  \
# Unique Key
# 38490120    MANHATTAN                    995846.0                    236544.0
#
#            Open Data Channel Type                                 Location
# Unique Key
# 38490120                   ONLINE  (40.81592674227958, -73.95810673319008)

# %% [markdown]
# Fixing the incident zip datatype after filling in NaN values

# %%
raw_data.fillna("00000", inplace=True)
raw_data['Incident Zip'] = raw_data['Incident Zip'].astype('float')
raw_data['Incident Zip'] = raw_data['Incident Zip'].astype('int')
raw_data.head(1)
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 38490120    02/17/2018 10:03:19 AM  02/17/2018 10:42:22 AM   NYPD
#
#                                 Agency Name       Complaint Type  \
# Unique Key
# 38490120    New York City Police Department  Noise - Residential
#
#                   Descriptor               Location Type  Incident Zip  \
# Unique Key
# 38490120    Loud Music/Party  Residential Building/House         10027
#
#               Borough X Coordinate (State Plane) Y Coordinate (State Plane)  \
# Unique Key
# 38490120    MANHATTAN                     995846                     236544
#
#            Open Data Channel Type                                 Location
# Unique Key
# 38490120                   ONLINE  (40.81592674227958, -73.95810673319008)

# %% [markdown]
# Creating Population column

# %%
raw_data.loc[:,'Population'] = pd.Series(0, index=raw_data.index)
raw_data.head(3)
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 38490120    02/17/2018 10:03:19 AM  02/17/2018 10:42:22 AM   NYPD
# 38490121    02/17/2018 08:40:26 AM  02/17/2018 03:34:25 PM   NYPD
# 38490122    02/17/2018 08:32:52 PM  02/17/2018 11:35:48 PM   NYPD
#
#                                 Agency Name       Complaint Type  \
# Unique Key
# 38490120    New York City Police Department  Noise - Residential
# 38490121    New York City Police Department  Noise - Residential
# 38490122    New York City Police Department  Noise - Residential
#
#                   Descriptor               Location Type  Incident Zip  \
# Unique Key
# 38490120    Loud Music/Party  Residential Building/House         10027
# 38490121    Loud Music/Party  Residential Building/House         11223
# 38490122    Loud Music/Party  Residential Building/House         10461
#
#               Borough X Coordinate (State Plane) Y Coordinate (State Plane)  \
# Unique Key
# 38490120    MANHATTAN                     995846                     236544
# 38490121     BROOKLYN                     990992                     156670
# 38490122        BRONX                1.03131e+06                     249965
#
#            Open Data Channel Type                                 Location  \
# Unique Key
# 38490120                   ONLINE  (40.81592674227958, -73.95810673319008)
# 38490121                   ONLINE  (40.59669663536788, -73.97572291796888)
# 38490122                    PHONE   (40.8526457301192, -73.82990522576051)
#
#             Population
# Unique Key
# 38490120             0
# 38490121             0
# 38490122             0

# %%
census_df.drop(0, inplace=True)

# %%
len(census_df)
# Out:
# 1794

# %% [markdown]
# Mapping population information to zip<br><br>
# GEO.id2 is zipcode in the census_df

# %%
census_df.columns
# Out:
# Index(['GEO.id', 'GEO.id2', 'GEO.display-label', 'D001'], dtype='object')

# %%
pop_dict = {}

for index, row in census_df.iterrows():    
    pop_dict[row['GEO.id2']] = pop_dict.get(row['GEO.id2'], row.D001)

# %%
raw_data['Incident Zip'] = raw_data['Incident Zip'].astype('str')
raw_data['Population'] = raw_data['Incident Zip'].map(pop_dict)
raw_data.head(3)
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 38490120    02/17/2018 10:03:19 AM  02/17/2018 10:42:22 AM   NYPD
# 38490121    02/17/2018 08:40:26 AM  02/17/2018 03:34:25 PM   NYPD
# 38490122    02/17/2018 08:32:52 PM  02/17/2018 11:35:48 PM   NYPD
#
#                                 Agency Name       Complaint Type  \
# Unique Key
# 38490120    New York City Police Department  Noise - Residential
# 38490121    New York City Police Department  Noise - Residential
# 38490122    New York City Police Department  Noise - Residential
#
#                   Descriptor               Location Type Incident Zip  \
# Unique Key
# 38490120    Loud Music/Party  Residential Building/House        10027
# 38490121    Loud Music/Party  Residential Building/House        11223
# 38490122    Loud Music/Party  Residential Building/House        10461
#
#               Borough X Coordinate (State Plane) Y Coordinate (State Plane)  \
# Unique Key
# 38490120    MANHATTAN                     995846                     236544
# 38490121     BROOKLYN                     990992                     156670
# 38490122        BRONX                1.03131e+06                     249965
#
#            Open Data Channel Type                                 Location  \
# Unique Key
# 38490120                   ONLINE  (40.81592674227958, -73.95810673319008)
# 38490121                   ONLINE  (40.59669663536788, -73.97572291796888)
# 38490122                    PHONE   (40.8526457301192, -73.82990522576051)
#
#            Population
# Unique Key
# 38490120        59707
# 38490121        78731
# 38490122        50502

# %% [markdown]
# Checked to ensure correct mapping

# %%
print(pop_dict['10027'])
print(pop_dict['11223'])
print(pop_dict['10461'])
# Out:
# 59707
# 78731
# 50502

# %%
raw_data.dtypes
# Out:
# Created Date                  object
# Closed Date                   object
# Agency                        object
# Agency Name                   object
# Complaint Type                object
# Descriptor                    object
# Location Type                 object
# Incident Zip                  object
# Borough                       object
# X Coordinate (State Plane)    object
# Y Coordinate (State Plane)    object
# Open Data Channel Type        object
# Location                      object
# Population                    object
# dtype: object

# %% [markdown]
# Now mapping neighborhoods onto zipcode as well

# %%
hood_path = str(Path.cwd().joinpath('calls/neighborhood.csv'))
hoods = pd.read_csv(hood_path, index_col=0)
hoods_dict = hoods.to_dict(orient='index')
for k, v in hoods_dict.items():
    hoods_dict[k] = hoods_dict[k]['Neighborhood']

# %%
# hoods.head()

# %%
hoods_dict
# Out:
# {10001: 'Chelsea and Clinton',
#  10002: 'Lower East Side',
#  10003: 'Lower East Side',
#  10004: 'Lower Manhattan',
#  10005: 'Lower Manhattan',
#  10006: 'Lower Manhattan',
#  10007: 'Lower Manhattan',
#  10009: 'Lower East Side',
#  10010: 'Gramercy Park and Murray Hill',
#  10011: 'Chelsea and Clinton',
#  10012: 'Greenwich Village and Soho',
#  10013: 'Greenwich Village and Soho',
#  10014: 'Greenwich Village and Soho',
#  10016: 'Gramercy Park and Murray Hill',
#  10017: 'Gramercy Park and Murray Hill',
#  10018: 'Chelsea and Clinton',
#  10019: 'Chelsea and Clinton',
#  10020: 'Chelsea and Clinton',
#  10021: 'Upper East Side',
#  10022: 'Gramercy Park and Murray Hill',
#  10023: 'Upper West Side',
#  10024: 'Upper West Side',
#  10025: 'Upper West Side',
#  10026: 'Central Harlem',
#  10027: 'Central Harlem',
#  10028: 'Upper East Side',
#  10029: 'East Harlem',
#  10030: 'Central Harlem',
#  10031: 'Inwood and Washington Heights',
#  10032: 'Inwood and Washington Heights',
#  10033: 'Inwood and Washington Heights',
#  10034: 'Inwood and Washington Heights',
#  10035: 'East Harlem',
#  10036: 'Chelsea and Clinton',
#  10037: 'Central Harlem',
#  10038: 'Lower Manhattan',
#  10039: 'Central Harlem',
#  10040: 'Inwood and Washington Heights',
#  10044: 'Upper East Side',
#  10065: 'Upper East Side',
#  10075: 'Upper East Side',
#  10128: 'Upper East Side',
#  10280: 'Lower Manhattan',
#  10301: 'Stapleton and St. George',
#  10302: 'Port Richmond',
#  10303: 'Port Richmond',
#  10304: 'Stapleton and St. George',
#  10305: 'Stapleton and St. George',
#  10306: 'South Shore',
#  10307: 'South Shore',
#  10308: 'South Shore',
#  10309: 'South Shore',
#  10310: 'Port Richmond',
#  10312: 'South Shore',
#  10314: 'Mid-Island',
#  10451: 'High Bridge and Morrisania',
#  10452: 'High Bridge and Morrisania',
#  10453: 'Central Bronx',
#  10454: 'Hunts Point and Mott Haven',
#  10455: 'Hunts Point and Mott Haven',
#  10456: 'High Bridge and Morrisania',
#  10457: 'Central Bronx',
#  10458: 'Bronx Park and Fordham',
#  10459: 'Hunts Point and Mott Haven',
#  10460: 'Central Bronx',
#  10461: 'Southeast Bronx',
#  10462: 'Southeast Bronx',
#  10463: 'Kingsbridge and Riverdale',
#  10464: 'Southeast Bronx',
#  10465: 'Southeast Bronx',
#  10466: 'Northeast Bronx',
#  10467: 'Bronx Park and Fordham',
#  10468: 'Bronx Park and Fordham',
#  10469: 'Northeast Bronx',
#  10470: 'Northeast Bronx',
#  10471: 'Kingsbridge and Riverdale',
#  10472: 'Southeast Bronx',
#  10473: 'Southeast Bronx',
#  10474: 'Hunts Point and Mott Haven',
#  10475: 'Northeast Bronx',
#  11004: 'Southeast Queens',
#  11005: 'Southeast Queens',
#  11101: 'Northwest Queens',
#  11102: 'Northwest Queens',
#  11103: 'Northwest Queens',
#  11104: 'Northwest Queens',
#  11105: 'Northwest Queens',
#  11106: 'Northwest Queens',
#  11201: 'Northwest Brooklyn',
#  11203: 'Flatbush',
#  11204: 'Borough Park',
#  11205: 'Northwest Brooklyn',
#  11206: 'Bushwick and Williamsburg',
#  11207: 'East New York and New Lots',
#  11208: 'East New York and New Lots',
#  11209: 'Southwest Brooklyn',
#  11210: 'Flatbush',
#  11211: 'Greenpoint',
#  11212: 'Central Brooklyn',
#  11213: 'Central Brooklyn',
#  11214: 'Southwest Brooklyn',
#  11215: 'Northwest Brooklyn',
#  11216: 'Central Brooklyn',
#  11217: 'Northwest Brooklyn',
#  11218: 'Borough Park',
#  11219: 'Borough Park',
#  11220: 'Sunset Park',
#  11221: 'Bushwick and Williamsburg',
#  11222: 'Greenpoint',
#  11223: 'Southern Brooklyn',
#  11224: 'Southern Brooklyn',
#  11225: 'Flatbush',
#  11226: 'Flatbush',
#  11228: 'Southwest Brooklyn',
#  11229: 'Southern Brooklyn',
#  11230: 'Borough Park',
#  11231: 'Northwest Brooklyn',
#  11232: 'Sunset Park',
#  11233: 'Central Brooklyn',
#  11234: 'Canarsie and Flatlands',
#  11235: 'Southern Brooklyn',
#  11236: 'Canarsie and Flatlands',
#  11237: 'Bushwick and Williamsburg',
#  11238: 'Central Brooklyn',
#  11239: 'Canarsie and Flatlands',
#  11354: 'North Queens',
#  11355: 'North Queens',
#  11356: 'North Queens',
#  11357: 'North Queens',
#  11358: 'North Queens',
#  11359: 'North Queens',
#  11360: 'North Queens',
#  11361: 'Northeast Queens',
#  11362: 'Northeast Queens',
#  11363: 'Northeast Queens',
#  11364: 'Northeast Queens',
#  11365: 'Central Queens',
#  11366: 'Central Queens',
#  11367: 'Central Queens',
#  11368: 'West Queens',
#  11369: 'West Queens',
#  11370: 'West Queens',
#  11372: 'West Queens',
#  11373: 'West Queens',
#  11374: 'West Central Queens',
#  11375: 'West Central Queens',
#  11377: 'West Queens',
#  11378: 'West Queens',
#  11379: 'West Central Queens',
#  11385: 'West Central Queens',
#  11411: 'Southeast Queens',
#  11412: 'Jamaica',
#  11413: 'Southeast Queens',
#  11414: 'Southwest Queens',
#  11415: 'Southwest Queens',
#  11416: 'Southwest Queens',
#  11417: 'Southwest Queens',
#  11418: 'Southwest Queens',
#  11419: 'Southwest Queens',
#  11420: 'Southwest Queens',
#  11421: 'Southwest Queens',
#  11422: 'Southeast Queens',
#  11423: 'Jamaica',
#  11426: 'Southeast Queens',
#  11427: 'Southeast Queens',
#  11428: 'Southeast Queens',
#  11429: 'Southeast Queens',
#  11432: 'Jamaica',
#  11433: 'Jamaica',
#  11434: 'Jamaica',
#  11435: 'Jamaica',
#  11436: 'Jamaica',
#  11691: 'Rockaways',
#  11692: 'Rockaways',
#  11693: 'Rockaways',
#  11694: 'Rockaways',
#  11695: 'Rockaways',
#  11697: 'Rockaways'}

# %%
raw_data['Incident Zip'] = raw_data['Incident Zip'].astype('int')
raw_data['Neighborhood'] = raw_data['Incident Zip'].map(hoods_dict)

# %%
raw_data.head()
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 38490120    02/17/2018 10:03:19 AM  02/17/2018 10:42:22 AM   NYPD
# 38490121    02/17/2018 08:40:26 AM  02/17/2018 03:34:25 PM   NYPD
# 38490122    02/17/2018 08:32:52 PM  02/17/2018 11:35:48 PM   NYPD
# 38490123    02/17/2018 02:07:29 PM  02/17/2018 02:21:28 PM   NYPD
# 38490124    02/17/2018 10:52:04 PM  02/18/2018 01:30:55 AM   NYPD
#
#                                 Agency Name       Complaint Type  \
# Unique Key
# 38490120    New York City Police Department  Noise - Residential
# 38490121    New York City Police Department  Noise - Residential
# 38490122    New York City Police Department  Noise - Residential
# 38490123    New York City Police Department  Noise - Residential
# 38490124    New York City Police Department  Noise - Residential
#
#                   Descriptor               Location Type  Incident Zip  \
# Unique Key
# 38490120    Loud Music/Party  Residential Building/House         10027
# 38490121    Loud Music/Party  Residential Building/House         11223
# 38490122    Loud Music/Party  Residential Building/House         10461
# 38490123    Loud Music/Party  Residential Building/House         10002
# 38490124    Loud Music/Party  Residential Building/House         11385
#
#               Borough X Coordinate (State Plane) Y Coordinate (State Plane)  \
# Unique Key
# 38490120    MANHATTAN                     995846                     236544
# 38490121     BROOKLYN                     990992                     156670
# 38490122        BRONX                1.03131e+06                     249965
# 38490123    MANHATTAN                     987058                     198677
# 38490124       QUEENS                1.01212e+06                     191989
#
#            Open Data Channel Type                                  Location  \
# Unique Key
# 38490120                   ONLINE   (40.81592674227958, -73.95810673319008)
# 38490121                   ONLINE   (40.59669663536788, -73.97572291796888)
# 38490122                    PHONE    (40.8526457301192, -73.82990522576051)
# 38490123                    PHONE   (40.71199877267997, -73.98987125976987)
# 38490124                    PHONE  (40.693598357245065, -73.89951223535249)
#
#            Population         Neighborhood
# Unique Key
# 38490120        59707       Central Harlem
# 38490121        78731    Southern Brooklyn
# 38490122        50502      Southeast Bronx
# 38490123        81410      Lower East Side
# 38490124        98592  West Central Queens

# %% [markdown]
# For each zip code (and for each neighborhood)
#
# Calls/person
# Calls of each type/person

# %% [markdown]
# ### Creating the neighborhoods information
# Scrapped a website to get the zips by neighborhood info using requests and BeautifulSoup; did some manipulation

# %%
# import urllib.request, urllib.parse, urllib.error
# from bs4 import BeautifulSoup
# import ssl
# import pandas as pd

# ctx = ssl.create_default_context()
# ctx.check_hostname = False
# ctx.verify_mode = ssl.CERT_NONE

# url = input('Enter - ')
# if len(url) < 1: url = 'https://www.health.ny.gov/statistics/cancer/registry/appendix/neighborhoods.htm'

# soup = BeautifulSoup(urllib.request.urlopen(url, context=ctx).read(), 'html.parser')

# tags = soup('td')

# #Pass tags to this function. It will pull out each neighborhood and each set of zip codes,
# #and then zip those together into a dictionary with neighborhoods paired to their zipcodes

# def create_hood_dict(tag_list):
#     neighborhood = []
#     zip_codes = []
#     for tag in tag_list:
#         if str(tag).startswith('<td headers="header2">'):
#             hood = tag.text.lstrip()
#             neighborhood.append(hood)
#         elif str(tag).startswith('<td headers="header3">'):
#             zips_1 = tag.text.split(",")
#             zips_2 = [zip.lstrip() for zip in zips_1]
#             zip_codes.append(zips_2)
#         else:
#             continue
#     result = zip(neighborhood, zip_codes)
#     neighborhoods_local = dict(result)
#     return neighborhoods_local


# def persist(dict_name):
#     better_dict = {}
    
#     for k, v in dict_name.items():
#         for zipcode in v: 
#             better_dict[zipcode] = better_dict.get(zipcode, k)
            
#     data = test3 = pd.DataFrame.from_dict(better_dict, orient = 'index', columns = ['Neighborhood'])
#     data.to_csv('calls/neighborhood.csv', mode = 'w+')
#     return data
# Out:
# Enter -

# %%
hood_dict = create_hood_dict(tags)
test1 = persist(hood_dict)

# %%
hood_dict
# Out:
# {'Borough Park': ['11204.0', '11218.0', '11219.0', '11230.0'],
#  'Bronx Park and Fordham': ['10458.0', '10467.0', '10468.0'],
#  'Bushwick and Williamsburg': ['11206.0', '11221.0', '11237.0'],
#  'Canarsie and Flatlands': ['11234.0', '11236.0', '11239.0'],
#  'Central Bronx': ['10453.0', '10457.0', '10460.0'],
#  'Central Brooklyn': ['11212.0', '11213.0', '11216.0', '11233.0', '11238.0'],
#  'Central Harlem': ['10026.0', '10027.0', '10030.0', '10037.0', '10039.0'],
#  'Central Queens': ['11365.0', '11366.0', '11367.0'],
#  'Chelsea and Clinton': ['10001.0',
#   '10011.0',
#   '10018.0',
#   '10019.0',
#   '10020.0',
#   '10036.0'],
#  'East Harlem': ['10029.0', '10035.0'],
#  'East New York and New Lots': ['11207.0', '11208.0'],
#  'Flatbush': ['11203.0', '11210.0', '11225.0', '11226.0'],
#  'Gramercy Park and Murray Hill': ['10010.0', '10016.0', '10017.0', '10022.0'],
#  'Greenpoint': ['11211.0', '11222.0'],
#  'Greenwich Village and Soho': ['10012.0', '10013.0', '10014.0'],
#  'High Bridge and Morrisania': ['10451.0', '10452.0', '10456.0'],
#  'Hunts Point and Mott Haven': ['10454.0', '10455.0', '10459.0', '10474.0'],
#  'Inwood and Washington Heights': ['10031.0',
#   '10032.0',
#   '10033.0',
#   '10034.0',
#   '10040.0'],
#  'Jamaica': ['11412.0',
#   '11423.0',
#   '11432.0',
#   '11433.0',
#   '11434.0',
#   '11435.0',
#   '11436.0'],
#  'Kingsbridge and Riverdale': ['10463.0', '10471.0'],
#  'Lower East Side': ['10002.0', '10003.0', '10009.0'],
#  'Lower Manhattan': ['10004.0',
#   '10005.0',
#   '10006.0',
#   '10007.0',
#   '10038.0',
#   '10280.0'],
#  'Mid-Island': ['10314.0'],
#  'North Queens': ['11354.0',
#   '11355.0',
#   '11356.0',
#   '11357.0',
#   '11358.0',
#   '11359.0',
#   '11360.0'],
#  'Northeast Bronx': ['10466.0', '10469.0', '10470.0', '10475.0'],
#  'Northeast Queens': ['11361.0', '11362.0', '11363.0', '11364.0'],
#  'Northwest Brooklyn': ['11201.0', '11205.0', '11215.0', '11217.0', '11231.0'],
#  'Northwest Queens': ['11101.0',
#   '11102.0',
#   '11103.0',
#   '11104.0',
#   '11105.0',
#   '11106.0'],
#  'Port Richmond': ['10302.0', '10303.0', '10310.0'],
#  'Rockaways': ['11691.0',
#   '11692.0',
#   '11693.0',
#   '11694.0',
#   '11695.0',
#   '11697.0'],
#  'South Shore': ['10306.0', '10307.0', '10308.0', '10309.0', '10312.0'],
#  'Southeast Bronx': ['10461.0',
#   '10462.0',
#   '10464.0',
#   '10465.0',
#   '10472.0',
#   '10473.0'],
#  'Southeast Queens': ['11004.0',
#   '11005.0',
#   '11411.0',
#   '11413.0',
#   '11422.0',
#   '11426.0',
#   '11427.0',
#   '11428.0',
#   '11429.0'],
#  'Southern Brooklyn': ['11223.0', '11224.0', '11229.0', '11235.0'],
#  'Southwest Brooklyn': ['11209.0', '11214.0', '11228.0'],
#  'Southwest Queens': ['11414.0',
#   '11415.0',
#   '11416.0',
#   '11417.0',
#   '11418.0',
#   '11419.0',
#   '11420.0',
#   '11421.0'],
#  'Stapleton and St. George': ['10301.0', '10304.0', '10305.0'],
#  'Sunset Park': ['11220.0', '11232.0'],
#  'Upper East Side': ['10021.0',
#   '10028.0',
#   '10044.0',
#   '10065.0',
#   '10075.0',
#   '10128.0'],
#  'Upper West Side': ['10023.0', '10024.0', '10025.0'],
#  'West Central Queens': ['11374.0', '11375.0', '11379.0', '11385.0'],
#  'West Queens': ['11368.0',
#   '11369.0',
#   '11370.0',
#   '11372.0',
#   '11373.0',
#   '11377.0',
#   '11378.0']}

# %%
test1
# Out:
#                         Neighborhood
# 11101               Northwest Queens
# 10018            Chelsea and Clinton
# 10025                Upper West Side
# 10466                Northeast Bronx
# 10301       Stapleton and St. George
# 11411               Southeast Queens
# 10033  Inwood and Washington Heights
# 10006                Lower Manhattan
# 11212               Central Brooklyn
# 11691                      Rockaways
# 10044                Upper East Side
# 11206      Bushwick and Williamsburg
# 10007                Lower Manhattan
# 11373                    West Queens
# 11694                      Rockaways
# 10471      Kingsbridge and Riverdale
# 11209             Southwest Brooklyn
# 10075                Upper East Side
# 10472                Southeast Bronx
# 11419               Southwest Queens
# 11237      Bushwick and Williamsburg
# 10009                Lower East Side
# 11414               Southwest Queens
# 10034  Inwood and Washington Heights
# 11378                    West Queens
# 11423                        Jamaica
# 10469                Northeast Bronx
# 10309                    South Shore
# 11433                        Jamaica
# 10026                 Central Harlem
# ...                              ...
# 11375            West Central Queens
# 11205             Northwest Brooklyn
# 11213               Central Brooklyn
# 10019            Chelsea and Clinton
# 10040  Inwood and Washington Heights
# 10035                    East Harlem
# 11358                   North Queens
# 11215             Northwest Brooklyn
# 10474     Hunts Point and Mott Haven
# 11421               Southwest Queens
# 11103               Northwest Queens
# 11214             Southwest Brooklyn
# 11211                     Greenpoint
# 10312                    South Shore
# 10020            Chelsea and Clinton
# 11422               Southeast Queens
# 10002                Lower East Side
# 11232                    Sunset Park
# 11203                       Flatbush
# 10017  Gramercy Park and Murray Hill
# 11428               Southeast Queens
# 10306                    South Shore
# 10021                Upper East Side
# 11435                        Jamaica
# 11369                    West Queens
# 11105               Northwest Queens
# 10011            Chelsea and Clinton
# 10461                Southeast Bronx
# 10452     High Bridge and Morrisania
# 11225                       Flatbush
#
# [178 rows x 1 columns]

# %%
raw_data.head(3)
# Out:
#                       Created Date             Closed Date Agency  \
# Unique Key
# 38490120    02/17/2018 10:03:19 AM  02/17/2018 10:42:22 AM   NYPD
# 38490121    02/17/2018 08:40:26 AM  02/17/2018 03:34:25 PM   NYPD
# 38490122    02/17/2018 08:32:52 PM  02/17/2018 11:35:48 PM   NYPD
#
#                                 Agency Name       Complaint Type  \
# Unique Key
# 38490120    New York City Police Department  Noise - Residential
# 38490121    New York City Police Department  Noise - Residential
# 38490122    New York City Police Department  Noise - Residential
#
#                   Descriptor               Location Type  Incident Zip  \
# Unique Key
# 38490120    Loud Music/Party  Residential Building/House         10027
# 38490121    Loud Music/Party  Residential Building/House         11223
# 38490122    Loud Music/Party  Residential Building/House         10461
#
#               Borough X Coordinate (State Plane) Y Coordinate (State Plane)  \
# Unique Key
# 38490120    MANHATTAN                     995846                     236544
# 38490121     BROOKLYN                     990992                     156670
# 38490122        BRONX                1.03131e+06                     249965
#
#            Open Data Channel Type                                 Location  \
# Unique Key
# 38490120                   ONLINE  (40.81592674227958, -73.95810673319008)
# 38490121                   ONLINE  (40.59669663536788, -73.97572291796888)
# 38490122                    PHONE   (40.8526457301192, -73.82990522576051)
#
#            Population       Neighborhood
# Unique Key
# 38490120        59707     Central Harlem
# 38490121        78731  Southern Brooklyn
# 38490122        50502    Southeast Bronx

# %%
# raw_dict = raw_data.to_dict(orient='index')

# %%
def total_complaints():
    total_complaints_dict = {}
    for i in list(set(raw_data['Incident Zip'])):
        total_complaints_dict[i] = total_complaints_dict.get(i, len(raw_data.loc[raw_data['Incident Zip'] == i]))
    return total_complaints_dict

total_complaints_dict = total_complaints()
total_complaints_dict
# Out:
# {0: 2791,
#  83: 36,
#  10000: 162,
#  10001: 3091,
#  10002: 10948,
#  10003: 6572,
#  10004: 229,
#  10005: 405,
#  10006: 172,
#  10007: 818,
#  10009: 9227,
#  10010: 1939,
#  10011: 4045,
#  10012: 4251,
#  10013: 2674,
#  10014: 3471,
#  10016: 3476,
#  10017: 1010,
#  10018: 1016,
#  10019: 2855,
#  10020: 25,
#  10021: 1731,
#  10022: 1450,
#  10023: 2517,
#  10024: 3095,
#  10025: 6637,
#  10026: 7152,
#  10027: 7672,
#  10028: 2501,
#  10029: 7590,
#  10030: 4500,
#  10031: 15036,
#  10032: 10794,
#  10033: 10117,
#  10034: 10215,
#  10035: 4279,
#  10036: 3783,
#  10037: 2105,
#  10038: 1248,
#  10039: 4713,
#  10040: 12228,
#  10041: 11,
#  10044: 48,
#  10048: 1,
#  10065: 1286,
#  10069: 58,
#  10075: 1256,
#  10103: 2,
#  10106: 2,
#  10107: 3,
#  10110: 3,
#  10111: 1,
#  10112: 5,
#  10118: 18,
#  10119: 12,
#  10120: 9,
#  10121: 38,
#  10122: 3,
#  10123: 1,
#  10128: 2658,
#  10151: 1,
#  10153: 1,
#  10155: 1,
#  10162: 9,
#  10165: 1,
#  10168: 1,
#  10169: 1,
#  10171: 1,
#  10172: 1,
#  10173: 3,
#  10175: 1,
#  10177: 3,
#  10178: 1,
#  10271: 1,
#  10278: 12,
#  10279: 1,
#  10280: 121,
#  10281: 17,
#  10282: 31,
#  10301: 3366,
#  10302: 1985,
#  10303: 2372,
#  10304: 3964,
#  10305: 2942,
#  10306: 4596,
#  10307: 1111,
#  10308: 2624,
#  10309: 2058,
#  10310: 2949,
#  10312: 4601,
#  10314: 6543,
#  10451: 4718,
#  10452: 9972,
#  10453: 8020,
#  10454: 2843,
#  10455: 4267,
#  10456: 10015,
#  10457: 9061,
#  10458: 8916,
#  10459: 5094,
#  10460: 5878,
#  10461: 2947,
#  10462: 4298,
#  10463: 6310,
#  10464: 337,
#  10465: 2552,
#  10466: 4549,
#  10467: 10435,
#  10468: 11343,
#  10469: 3496,
#  10470: 1133,
#  10471: 983,
#  10472: 8780,
#  10473: 3691,
#  10474: 1634,
#  10475: 308,
#  10583: 1,
#  11001: 85,
#  11004: 405,
#  11005: 1,
#  11040: 73,
#  11096: 1,
#  11101: 3422,
#  11102: 2727,
#  11103: 3798,
#  11104: 1737,
#  11105: 2133,
#  11106: 3184,
#  11109: 93,
#  11201: 3778,
#  11203: 5905,
#  11204: 2406,
#  11205: 7253,
#  11206: 10728,
#  11207: 8286,
#  11208: 7994,
#  11209: 4083,
#  11210: 3067,
#  11211: 10005,
#  11212: 5319,
#  11213: 7992,
#  11214: 2555,
#  11215: 5380,
#  11216: 10406,
#  11217: 5003,
#  11218: 4142,
#  11219: 2511,
#  11220: 6582,
#  11221: 12506,
#  11222: 4925,
#  11223: 2753,
#  11224: 2077,
#  11225: 9118,
#  11226: 12379,
#  11228: 1037,
#  11229: 3604,
#  11230: 3743,
#  11231: 2382,
#  11232: 2272,
#  11233: 7630,
#  11234: 3777,
#  11235: 4281,
#  11236: 4383,
#  11237: 12072,
#  11238: 10920,
#  11239: 145,
#  11241: 2,
#  11242: 1,
#  11249: 4228,
#  11354: 1672,
#  11355: 1684,
#  11356: 1454,
#  11357: 1132,
#  11358: 1179,
#  11360: 315,
#  11361: 989,
#  11362: 326,
#  11363: 131,
#  11364: 606,
#  11365: 1123,
#  11366: 852,
#  11367: 1302,
#  11368: 6419,
#  11369: 2237,
#  11370: 1108,
#  11372: 3581,
#  11373: 3766,
#  11374: 1217,
#  11375: 2221,
#  11377: 4239,
#  11378: 1568,
#  11379: 1132,
#  11385: 7983,
#  11411: 578,
#  11412: 1682,
#  11413: 1376,
#  11414: 1421,
#  11415: 1027,
#  11416: 1982,
#  11417: 2378,
#  11418: 2963,
#  11419: 4346,
#  11420: 4153,
#  11421: 3548,
#  11422: 1060,
#  11423: 1682,
#  11426: 614,
#  11427: 829,
#  11428: 1003,
#  11429: 884,
#  11430: 10,
#  11432: 2865,
#  11433: 2453,
#  11434: 2540,
#  11435: 2541,
#  11436: 1263,
#  11691: 3290,
#  11692: 960,
#  11693: 1032,
#  11694: 1210,
#  11697: 16,
#  12345: 1}

# %%
raw_data['Descriptor'] = raw_data['Descriptor'].astype('str')

def specific_complaint_type_count(complaint_type):
    specific_complaints_dict = {}
    for i in list(set(raw_data['Incident Zip'])):
        specific_complaints_dict[i] = specific_complaints_dict.get(i, len(raw_data.loc([raw_data['Incident Zip'] == i]
                                                                    & raw_data.loc[raw_data['Descriptor'] == complaint_type])))
    return specific_complaints_dict

specific_complaints_dict = specific_complaint_type_count('Loud Music/Party')
specific_complaints_dict
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-182-70a85c358e24> in <module>()
#       8     return specific_complaints_dict
#       9
# ---> 10 specific_complaints_dict = specific_complaint_type_count('Loud Music/Party')
#      11 specific_complaints_dict
#
# <ipython-input-182-70a85c358e24> in specific_complaint_type_count(complaint_type)
#       5     for i in list(set(raw_data['Incident Zip'])):
#       6         specific_complaints_dict[i] = specific_complaints_dict.get(i, len(raw_data.loc([raw_data['Incident Zip'] == i]
# ----> 7                                                                     & raw_data.loc[raw_data['Descriptor'] == complaint_type])))
#       8     return specific_complaints_dict
#       9
#
# /anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in f(self, other, axis, level, fill_value)
#    1545     def f(self, other, axis=default_axis, level=None, fill_value=None):
#    1546
# -> 1547         other = _align_method_FRAME(self, other, axis)
#    1548
#    1549         if isinstance(other, ABCDataFrame):  # Another DataFrame
#
# /anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in _align_method_FRAME(left, right, axis)
#    1479           not isinstance(right, (ABCSeries, ABCDataFrame))):
#    1480         # GH17901
# -> 1481         right = to_series(right)
#    1482
#    1483     return right
#
# /anaconda3/lib/python3.5/site-packages/pandas/core/ops.py in to_series(right)
#    1454             if len(left.columns) != len(right):
#    1455                 raise ValueError(msg.format(req_len=len(left.columns),
# -> 1456                                             given_len=len(right)))
#    1457             right = left._constructor_sliced(right, index=left.columns)
#    1458         return right
#
# ValueError: Unable to coerce to Series, length must be 15: given 1

# %%
# now call them, and build out a dataframe, then get your 'max', 'min' 'avg' and per capita of those

# %%
len(list(set(raw_data['Incident Zip'])))
# Out:
# 222

# %%
& df['other_column'].isin(some_values)]

# %% [markdown]
# ## Updating SQL Database

# %% [markdown]
# Notes on creating and populating a new column, courtesy of StackOverflow
#
# ALTER TABLE table ADD COLUMN col3 desired_datatype;
#
# SELECT a, b, (case when (a + b) % 2 = 1 then 'Y' else 'N' end) AS col3 FROM table t;
#
# OR
#
# UPDATE table SET col3 = (case when (a + b) % 2 = 1 then 'Y' else 'N' end) ;

# %% [markdown]
# ## The Important Code

# %%
test_44 = pd.read_sql("SELECT * FROM locations", conn, index_col = "id")

# %%
#Fixing Datatype 

test_44['zip'] = test_44['zip'].astype('float')
test_44['zip'] = test_44['zip'].astype('int')

#Population 

test_44['zip']= test_44['zip'].astype('str')
test_44['population'] = test_44['zip'].map(pop_dict)

#Neighborhoods 

test_44['zip'] = test_44['zip'].astype('int')
test_44['neighborhood'] = test_44['zip'].map(hoods_dict)

# %%
test_44.isna().sum()
# Out:
# zip              0
# borough_id       0
# population      21
# neighborhood    46
# dtype: int64

# %%
# I was getting an error about NaN values, apparently some of these zipcodes don't belong to any neighborhood
# or a listed population 

test_44.fillna({'population':0, 'neighborhood':'Undefined'}, inplace=True)
test_44['neighborhood'] = test_44['neighborhood'].astype('str')
test_44['population'] = test_44['population'].astype('int')

# %%
test_44.head()
# Out:
#       zip  borough_id  population         neighborhood
# id
# 1   10027           1       59707       Central Harlem
# 2   11223           2       78731    Southern Brooklyn
# 3   10461           3       50502      Southeast Bronx
# 4   10002           1       81410      Lower East Side
# 5   11385           4       98592  West Central Queens

# %%
test_44.to_sql("locations", conn, if_exists = 'replace', index_label = "id")

# %%
test_write_success = pd.read_sql("SELECT * FROM locations", conn, index_col = "id")
test_write_success.head()
# Out:
#       zip  borough_id  population         neighborhood
# id
# 1   10027           1       59707       Central Harlem
# 2   11223           2       78731    Southern Brooklyn
# 3   10461           3       50502      Southeast Bronx
# 4   10002           1       81410      Lower East Side
# 5   11385           4       98592  West Central Queens

# %%
test_write_success.shape
# Out:
# (222, 4)

# %%
test_write_success.dtypes
# Out:
# zip              int64
# borough_id       int64
# population       int64
# neighborhood    object
# dtype: object

# %% [markdown]
# ## Comparison Metrics

# %%
test_write_success.groupby('borough_id')['population'].sum()
# Out:
# borough_id
# 1    1577374
# 2    2504700
# 3    1382480
# 4    2311269
# 5     468730
# 6      38982
# Name: population, dtype: int64

# %%
neighborhood_pops = dict(test_write_success.groupby('neighborhood')['population'].sum())
# could also use list here!

# %%
test_write_success.groupby('zip')['population'].sum()
# Out:
# zip
# 0            0
# 83           0
# 10000        0
# 10001    21102
# 10002    81410
# 10003    56024
# 10004     3089
# 10005     7135
# 10006     3011
# 10007     6988
# 10009    61347
# 10010    31834
# 10011    50984
# 10012    24090
# 10013    27700
# 10014    31959
# 10016    54183
# 10017    16575
# 10018     5229
# 10019    42870
# 10020        0
# 10021    43631
# 10022    31924
# 10023    60998
# 10024    59283
# 10025    94600
# 10026    34003
# 10027    59707
# 10028    45141
# 10029    76003
#          ...
# 11385    98592
# 11411    18556
# 11412    34882
# 11413    38912
# 11414    26148
# 11415    19341
# 11416    24861
# 11417    28967
# 11418    36256
# 11419    47211
# 11420    44354
# 11421    39127
# 11422    30425
# 11423    29987
# 11426    17590
# 11427    23593
# 11428    19168
# 11429    25105
# 11430      184
# 11432    60809
# 11433    32687
# 11434    59129
# 11435    53687
# 11436    17949
# 11691    60035
# 11692    18540
# 11693    11916
# 11694    20408
# 11697     4079
# 12345        0
# Name: population, Length: 222, dtype: int64

# %% [markdown]
# ### Fixing "For One Address"

# %%
complaints_df = pd.read_sql("SELECT * FROM complaints", conn, index_col = "id")

# %%
complaints_df.head(3)
# Out:
#                 type  status  method        date agency_name  location_id  \
# id
# 1   Loud Music/Party  Closed  ONLINE  02/17/2018        NYPD            1
# 2   Loud Music/Party  Closed  ONLINE  02/17/2018        NYPD            2
# 3   Loud Music/Party  Closed   PHONE  02/17/2018        NYPD            3
#
#    borough_name
# id
# 1     MANHATTAN
# 2      BROOKLYN
# 3         BRONX

# %%
complaints_df.replace(to_replace = "For One Address", value = "Tree Request", inplace=True)

# %%
complaints_df.columns
# Out:
# Index(['type', 'status', 'method', 'date', 'agency_name', 'location_id',
#        'borough_name'],
#       dtype='object')

# %%
complaints_df.groupby('location_id').count()
# Out:
#               type  status  method   date  agency_name  borough_name
# location_id
# 1             7672    7672    7672   7672         7672          7672
# 2             2753    2753    2753   2753         2753          2753
# 3             2947    2947    2947   2947         2947          2947
# 4            10948   10948   10948  10948        10948         10948
# 5             7983    7983    7983   7983         7983          7983
# 6             6310    6310    6310   6310         6310          6310
# 7             7590    7590    7590   7590         7590          7590
# 8            10920   10920   10920  10920        10920         10920
# 9            10215   10215   10215  10215        10215         10215
# 10           10728   10728   10728  10728        10728         10728
# 11            1985    1985    1985   1985         1985          1985
# 12            7994    7994    7994   7994         7994          7994
# 13             829     829     829    829          829           829
# 14           10117   10117   10117  10117        10117         10117
# 15           15036   15036   15036  15036        15036         15036
# 16           12506   12506   12506  12506        12506         12506
# 17            4601    4601    4601   4601         4601          4601
# 18           10406   10406   10406  10406        10406         10406
# 19            3691    3691    3691   3691         3691          3691
# 20            4596    4596    4596   4596         4596          4596
# 21            2624    2624    2624   2624         2624          2624
# 22            7992    7992    7992   7992         7992          7992
# 23            4267    4267    4267   4267         4267          4267
# 24           12072   12072   12072  12072        12072         12072
# 25             818     818     818    818          818           818
# 26            3366    3366    3366   3366         3366          3366
# 27            5003    5003    5003   5003         5003          5003
# 28            1982    1982    1982   1982         1982          1982
# 29            8780    8780    8780   8780         8780          8780
# 30            3496    3496    3496   3496         3496          3496
# ...            ...     ...     ...    ...          ...           ...
# 193              9       9       9      9            9             9
# 194              5       5       5      5            5             5
# 195              1       1       1      1            1             1
# 196             36      36      36     36           36            36
# 197              1       1       1      1            1             1
# 198             17      17      17     17           17            17
# 199             12      12      12     12           12            12
# 200              1       1       1      1            1             1
# 201              3       3       3      3            3             3
# 202              3       3       3      3            3             3
# 203              1       1       1      1            1             1
# 204              1       1       1      1            1             1
# 205              1       1       1      1            1             1
# 206              3       3       3      3            3             3
# 207             11      11      11     11           11            11
# 208              1       1       1      1            1             1
# 209              1       1       1      1            1             1
# 210              1       1       1      1            1             1
# 211              1       1       1      1            1             1
# 212              1       1       1      1            1             1
# 213              1       1       1      1            1             1
# 214              1       1       1      1            1             1
# 215              2       2       2      2            2             2
# 216              2       2       2      2            2             2
# 217              3       3       3      3            3             3
# 218              1       1       1      1            1             1
# 219              1       1       1      1            1             1
# 220              1       1       1      1            1             1
# 221              1       1       1      1            1             1
# 222              1       1       1      1            1             1
#
# [222 rows x 6 columns]

# %%
complaints_df.to_sql("complaints", conn, if_exists = 'replace', index_label = "id")

# %%
conn.close()
